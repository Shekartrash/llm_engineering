# %% [markdown]
# # Welcome to a very busy Week 8 folder
#
# ## We have lots to do this week!
#
# We'll move at a faster pace than usual, particularly as you're becoming proficient LLM engineers.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Especially important this week: pull the latest</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a <a href="https://chatgpt.com/share/6734e705-3270-8012-a074-421661af6ba9">git pull and merge your changes as needed</a>. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/><br/>
#             After you've pulled the code, from the llm_engineering directory, in an Anaconda prompt (PC) or Terminal (Mac), run:<br/>
#             <code>conda env update --f environment.yml --prune</code><br/>
#             Or if you used virtualenv rather than Anaconda, then run this from your activated environment in a Powershell (PC) or Terminal (Mac):<br/>
#             <code>pip install -r requirements.txt</code>
#             <br/>Then restart the kernel (Kernel menu >> Restart Kernel and Clear Outputs Of All Cells) to pick up the changes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Just one import to start with!!

import modal

# %% [markdown]
# # Setting up the modal tokens
#
# The first time you run this, please uncomment the next line and execute it.
# This is the same as running `modal setup` from the command line. It connects with Modal and installs your tokens.
#
# A student on Windows mentioned that on Windows, you might also need to run this command from a command prompt afterwards:
# `modal token new`
# (Thank you Ed B. for that!)
#
# And I've also heard that in some situations, you might need to restart the Kernel of this jupyter notebook after running this. (Kernel menu >> Restart Kernel and Clear Outputs of All Cells).

# %%
# Remove the '# ' from the next line and run the cell
# !modal setup
# Out:
# ⠋ Waiting for authentication in the web browser
# ⠙ Waiting for authentication in the web browser
# ⠹ Waiting for authentication in the web browser
# ⠸ Waiting for authentication in the web browser
# ⠼ Waiting for authentication in the web browser
# ⠴ Waiting for authentication in the web browser
# ⠧ Waiting for authentication in the web browser
# ⠇ Waiting for authentication in the web browser
# ⠏ Waiting for authentication in the web browser
# ⠋ Waiting for authentication in the web browser
# ⠙ Waiting for authentication in the web browser
# ⠹ Waiting for authentication in the web browser
# ⠼ Waiting for authentication in the web browser
# ⠴ Waiting for authentication in the web browser
# ⠦ Waiting for authentication in the web browser
# ⠧ Waiting for authentication in the web browser
# ⠇ Waiting for authentication in the web browser
# ⠏ Waiting for authentication in the web browser
# The web browser should have opened for you to authenticate and get an API
# token.
# If it didn't, please copy this URL into your web browser manually:
#
# ⠋ Waiting for authentication in the web browser
# https://modal.com/token-flow/tf-jaLxGXVIcvxOXwe8aae0uY
#
# ⠋ Waiting for authentication in the web browser
# ⠋ Waiting for authentication in the web browser
#
# ⠋ Waiting for token flow to complete...
# ⠙ Waiting for token flow to complete...
# ⠹ Waiting for token flow to complete...
# ⠸ Waiting for token flow to complete...
# ⠼ Waiting for token flow to complete...
# ⠴ Waiting for token flow to complete...
# ⠧ Waiting for token flow to complete...
# ⠇ Waiting for token flow to complete...
# ⠏ Waiting for token flow to complete...
# ⠋ Waiting for token flow to complete...
# ⠙ Waiting for token flow to complete...
# ⠹ Waiting for token flow to complete...
# ⠸ Waiting for token flow to complete...
# ⠴ Waiting for token flow to complete...
# ⠦ Waiting for token flow to complete...
# ⠧ Waiting for token flow to complete...
# ⠇ Waiting for token flow to complete...
# ⠏ Waiting for token flow to complete...
# ⠋ Waiting for token flow to complete...
# ⠙ Waiting for token flow to complete...
# ⠸ Waiting for token flow to complete...
# ⠼ Waiting for token flow to complete...
# ⠴ Waiting for token flow to complete...
# ⠦ Waiting for token flow to complete...
# ⠧ Waiting for token flow to complete...
# ⠇ Waiting for token flow to complete...
# ⠋ Waiting for token flow to complete...
# ⠙ Waiting for token flow to complete...
# ⠹ Waiting for token flow to complete...
# ⠸ Waiting for token flow to complete...
# ⠼ Waiting for token flow to complete...
# ⠴ Waiting for token flow to complete...
# ⠧ Waiting for token flow to complete...
# ⠇ Waiting for token flow to complete...
# ⠏ Waiting for token flow to complete...
# ⠋ Waiting for token flow to complete...
# ⠙ Waiting for token flow to complete...
# ⠹ Waiting for token flow to complete...
# ⠸ Waiting for token flow to complete...
# ⠴ Waiting for token flow to complete...
# ⠦ Waiting for token flow to complete...
# ⠧ Waiting for token flow to complete...
# ⠇ Waiting for token flow to complete...
# ⠏ Waiting for token flow to complete...
# ⠋ Waiting for token flow to complete...
# ⠹ Waiting for token flow to complete...
# ⠸ Waiting for token flow to complete...
# ⠼ Waiting for token flow to complete...
# ⠴ Waiting for token flow to complete...
# ⠦ Waiting for token flow to complete...
# ⠧ Waiting for token flow to complete...
# ⠇ Waiting for token flow to complete...
# ⠋ Waiting for token flow to complete...
# ⠙ Waiting for token flow to complete...
# ⠹ Waiting for token flow to complete...
# ⠸ Waiting for token flow to complete...
# ⠼ Waiting for token flow to complete...
# ⠦ Waiting for token flow to complete...
# ⠧ Waiting for token flow to complete...
# ⠇ Waiting for token flow to complete...
# ⠏ Waiting for token flow to complete...
# ⠋ Waiting for token flow to complete...
# ⠙ Waiting for token flow to complete...
# ⠹ Waiting for token flow to complete...
# ⠼ Waiting for token flow to complete...
# ⠴ Waiting for token flow to complete...
# ⠦ Waiting for token flow to complete...
# ⠧ Waiting for token flow to complete...
# ⠇ Waiting for token flow to complete...
# ⠏ Waiting for token flow to complete...
# ⠋ Waiting for token flow to complete...
#
# Web authentication finished successfully!
# Token is connected to the shekartrash workspace.
# Verifying token against https://api.modal.com
# Token verified successfully!
# ⠋ Storing token
#
# Token written to C:\Users\e022280/.modal.toml in profile shekartrash.

# %%
from hello import app, hello

# %%
with app.run():
    reply=hello.local()
reply
# Out:
# 'Hello from Bengaluru, Karnataka, IN!!'

# %%
with app.run():
    reply=hello.remote()
reply
# Out:
# 'Hello from Ashburn, Virginia, US!!'

# %% [markdown]
# # Before we move on -
#
# ## We need to set your HuggingFace Token as a secret in Modal
#
# 1. Go to modal.com, sign in and go to your dashboard
# 2. Click on Secrets in the nav bar
# 3. Create new secret, click on Hugging Face, this new secret needs to be called **hf-secret** because that's how we refer to it in the code
# 4. Fill in your HF_TOKEN where it prompts you
#
# ### And now back to business: time to work with Llama

# %%
from llama import app, generate

# %%
with modal.enable_output():
    with app.run():
        result=generate.remote("Life is a mystery, everyone must stand alone, I hear")
result
# Out:
# Output()
# ✓ Initialized. View run at https://modal.com/apps/shekartrash/main/ap-n89e17jEsG3b6Xeoy8RUpA
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Building image im-1LYC3351Oygso6p9ogBoee
# => Step 0: FROM base
# => Step 1: RUN python -m pip install accelerate bitsandbytes torch transformers
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# Collecting accelerate
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.3.0-py3-none-any.whl.metadata (19 kB)
# Collecting bitsandbytes
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.2-py3-none-manylinux_2_24_x86_64.whl.metadata (5.8 kB)
# Collecting torch
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting transformers
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.48.3-py3-none-any.whl.metadata (44 kB)
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting packaging>=20.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting psutil (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyyaml (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface-hub>=0.21.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.28.1-py3-none-any.whl.metadata (13 kB)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting filelock (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/site-packages (from torch) (4.12.2)
# Collecting networkx (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.2.0 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting sympy==1.13.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting requests (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.3.0-py3-none-any.whl (336 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.2-py3-none-manylinux_2_24_x86_64.whl (69.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 425.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl (766.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 455.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 430.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 433.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 416.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 875.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 395.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 442.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 393.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 425.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 442.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 430.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 404.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 281.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl (6.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 271.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 287.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.48.3-py3-none-any.whl (9.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 236.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.28.1-py3-none-any.whl (464 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.2.0-py3-none-any.whl (184 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 333.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl (65 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 375.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 323.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (461 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 315.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.17.0-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.5-py3-none-any.whl (134 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 348.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (143 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 414.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.3.0-py3-none-any.whl (128 kB)
# Installing collected packages: triton, nvidia-cusparselt-cu12, mpmath, urllib3, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, charset-normalizer, requests, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, transformers, bitsandbytes, accelerate
# Successfully installed MarkupSafe-3.0.2 accelerate-1.3.0 bitsandbytes-0.45.2 charset-normalizer-3.4.1 filelock-3.17.0 fsspec-2025.2.0 huggingface-hub-0.28.1 jinja2-3.1.5 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 packaging-24.2 psutil-6.1.1 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 safetensors-0.5.2 sympy-1.13.1 tokenizers-0.21.0 torch-2.6.0 tqdm-4.67.1 transformers-4.48.3 triton-3.2.0 urllib3-2.3.0
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Saving image...
# Image saved, took 3.14s
# Built image im-1LYC3351Oygso6p9ogBoee in 71.44s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\llama.py
# ├── 🔨 Created mount PythonPackage:hello
# └── 🔨 Created function generate.
# Output()
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading shards:  25%|██▌       | 1/4 [07:58<23:54, 478.32s/it]
# Downloading shards:  50%|█████     | 2/4 [15:59<15:59, 479.72s/it]
# Downloading shards:  75%|███████▌  | 3/4 [23:51<07:56, 476.50s/it]
# Downloading shards: 100%|██████████| 4/4 [25:44<00:00, 332.75s/it]Downloading shards: 100%|██████████| 4/4 [25:44<00:00, 386.02s/it]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:06<00:19,  6.61s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:12<00:12,  6.38s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:18<00:05,  5.91s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:19<00:00,  4.09s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:19<00:00,  4.87s/it]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at https://modal.com/apps/shekartrash/main/ap-n89e17jEsG3b6Xeoy8RUpA
# '<|begin_of_text|>Life is a mystery, everyone must stand alone, I hear you call my name,'

# %%
import modal
from pricer_ephemeral import app, price

# %%
with modal.enable_output():
    with app.run():
        result=price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
result
# Out:
# Output()
# ✓ Initialized. View run at https://modal.com/apps/shekartrash/main/ap-bJccSw6S6tdrhWgfUgDxKu
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Building image im-jZiZAsI911AuW0Yb2Jwmmu
# => Step 0: FROM base
# => Step 1: RUN python -m pip install accelerate bitsandbytes peft torch transformers
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# Collecting accelerate
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.3.0-py3-none-any.whl.metadata (19 kB)
# Collecting bitsandbytes
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.2-py3-none-manylinux_2_24_x86_64.whl.metadata (5.8 kB)
# Collecting peft
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.14.0-py3-none-any.whl.metadata (13 kB)
# Collecting torch
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting transformers
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.48.3-py3-none-any.whl.metadata (44 kB)
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting packaging>=20.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting psutil (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyyaml (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface-hub>=0.21.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.28.1-py3-none-any.whl.metadata (13 kB)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tqdm (from peft)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting filelock (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/site-packages (from torch) (4.12.2)
# Collecting networkx (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.2.0 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting sympy==1.13.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting requests (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.3.0-py3-none-any.whl (336 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.2-py3-none-manylinux_2_24_x86_64.whl (69.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 318.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.14.0-py3-none-any.whl (374 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl (766.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 355.3 MB/s eta 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 448.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 483.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 493.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 817.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 459.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 431.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 474.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 473.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 539.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 541.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 532.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 495.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl (6.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 498.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 472.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.48.3-py3-none-any.whl (9.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 542.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.28.1-py3-none-any.whl (464 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.2.0-py3-none-any.whl (184 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 592.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl (65 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 1.1 GB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 291.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (461 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 538.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.17.0-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.5-py3-none-any.whl (134 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 707.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (143 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 942.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.3.0-py3-none-any.whl (128 kB)
# Installing collected packages: triton, nvidia-cusparselt-cu12, mpmath, urllib3, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, charset-normalizer, requests, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# Successfully installed MarkupSafe-3.0.2 accelerate-1.3.0 bitsandbytes-0.45.2 charset-normalizer-3.4.1 filelock-3.17.0 fsspec-2025.2.0 huggingface-hub-0.28.1 jinja2-3.1.5 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 packaging-24.2 peft-0.14.0 psutil-6.1.1 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 safetensors-0.5.2 sympy-1.13.1 tokenizers-0.21.0 torch-2.6.0 tqdm-4.67.1 transformers-4.48.3 triton-3.2.0 urllib3-2.3.0
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Saving image...
# Image saved, took 3.54s
# Built image im-jZiZAsI911AuW0Yb2Jwmmu in 73.09s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_ephemeral.py
# ├── 🔨 Created mount PythonPackage:llama
# ├── 🔨 Created mount PythonPackage:hello
# └── 🔨 Created function price.
# Output()
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading shards:  25%|██▌       | 1/4 [07:58<23:54, 478.21s/it]
# Downloading shards:  50%|█████     | 2/4 [15:58<15:59, 479.57s/it]
# Downloading shards:  75%|███████▌  | 3/4 [23:51<07:56, 476.36s/it]
# Downloading shards: 100%|██████████| 4/4 [25:43<00:00, 332.66s/it]Downloading shards: 100%|██████████| 4/4 [25:43<00:00, 385.91s/it]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:06<00:20,  6.72s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:13<00:13,  6.80s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:20<00:06,  6.80s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:22<00:00,  4.79s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:22<00:00,  5.52s/it]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at https://modal.com/apps/shekartrash/main/ap-bJccSw6S6tdrhWgfUgDxKu
# 133.0

# %% [markdown]
# ## Transitioning From Ephemeral Apps to Deployed Apps
#
# From a command line, `modal deploy xxx` will deploy your code as a Deployed App
#
# This is how you could package your AI service behind an API to be used in a Production System.
#
# You can also build REST endpoints easily, although we won't cover that as we'll be calling direct from Python.
#
# ## Important note for Windows people:
#
# On the next line, I call `modal deploy` from within Jupyter lab; I've heard that on some versions of Windows this gives a strange unicode error because modal prints emojis to the output which can't be displayed. If that happens to you, simply use an Anaconda Prompt window or a Powershell instead, with your environment activated, and type `modal deploy pricer_service` there. Follow the same approach the next time we do `!modal deploy` too.
#
# As an alternative, a few students have mentioned you can run this code within Jupyter Lab if you want to run it from here:
# ```
# # Check the default encoding
# print(locale.getpreferredencoding())  # Should print 'UTF-8'
#
# # Ensure UTF-8 encoding
# os.environ['PYTHONIOENCODING'] = 'utf-8'
# ```

# %%
# !modal deploy pricer_service
# Out:
# - Creating objects...
# | Creating objects...
# / Creating objects...
# | Creating objects...
# └── - Creating mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service.py:
#     Uploaded 0/1 files
# - Creating objects...
# └── | Creating mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service.py:
#     Uploaded 0/1 files
# | Creating objects...
# └── - Creating mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service.py:
#     Finalizing index of 1 files
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service.py
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service.py
# └── - Creating function price...
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service.py
# └── | Creating function price...
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service.py
# └── 🔨 Created function price.
#
# ✓ Created objects.
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service.py
# └── 🔨 Created function price.
# ✓ App deployed in 3.963s! 🎉
#
# View Deployment:
# https://modal.com/apps/shekartrash/main/deployed/pricer-service

# %%
pricer = modal.Function.lookup("pricer-service", "price")
# Out:
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py:84: DeprecationError: 2025-01-27: `modal.Function.lookup` is deprecated and will be removed in a future release. It can be replaced with `modal.Function.from_name`.
#
# See https://modal.com/docs/guide/modal-1-0-migration for more information.
#   self._context.run(self._callback, *self._args)

# %%
pricer.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
# Out:
# 133.0

# %%
# You can also run "modal deploy pricer_service2" at the command line in an activated environment
# !modal deploy pricer_service2
# Out:
# ┌─ Modal Deprecation Warning (2025-01-15) ────────────────────────────────────┐
# │ The `@modal.build` decorator is deprecated and will be removed in a future  │
# │ release.                                                                    │
# │                                                                             │
# │ We now recommend storing large assets (such as model weights) using a       │
# │ `modal.Volume` instead of writing them directly into the `modal.Image`      │
# │ filesystem. For other use cases we recommend using `Image.run_function`     │
# │ instead.                                                                    │
# │                                                                             │
# │ See https://modal.com/docs/guide/modal-1-0-migration for more information.  │
# │                                                                             │
# │ Source:                                                                     │
# │ c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py:30  │
# │   @modal.build()                                                            │
# └─────────────────────────────────────────────────────────────────────────────┘
# - Creating objects...
# \ Creating objects...
# / Creating objects...
# \ Creating objects...
# └── - Creating mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py:
#     Uploaded 0/1 files
# / Creating objects...
# └── \ Creating mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py:
#     Uploaded 0/1 files
# \ Creating objects...
# └── / Creating mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py:
#     Finalizing index of 1 files
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# Building image im-DTHFyFirReaoyvIE5L0XED
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#
# => Step 0: FROM base
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#
# => Step 1: RUN python -m pip install accelerate bitsandbytes huggingface peft torch transformers
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting accelerate
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.3.0-py3-none-any.whl.metadata (19 kB)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting bitsandbytes
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.2-py3-none-manylinux_2_24_x86_64.whl.metadata (5.8 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting huggingface
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl.metadata (2.9 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting peft
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.14.0-py3-none-any.whl.metadata (13 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting torch
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# Collecting transformers
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.48.3-py3-none-any.whl.metadata (44 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting packaging>=20.0 (from accelerate)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting psutil (from accelerate)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting pyyaml (from accelerate)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting huggingface-hub>=0.21.0 (from accelerate)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.28.1-py3-none-any.whl.metadata (13 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting safetensors>=0.4.3 (from accelerate)
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting tqdm (from peft)
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# Collecting filelock (from torch)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/site-packages (from torch) (4.12.2)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting networkx (from torch)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting jinja2 (from torch)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting fsspec (from torch)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.2.0-py3-none-any.whl.metadata (11 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting triton==3.2.0 (from torch)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting sympy==1.13.1 (from torch)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# Collecting regex!=2019.12.17 (from transformers)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# Collecting requests (from transformers)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting tokenizers<0.22,>=0.21 (from transformers)
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.3.0-py3-none-any.whl (336 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.45.2-py3-none-manylinux_2_24_x86_64.whl (69.7 MB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 243.2 MB/s eta 0:00:00
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.14.0-py3-none-any.whl (374 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl (766.7 MB)
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 288.0 MB/s eta 0:00:00
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 275.4 MB/s eta 0:00:00
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 245.8 MB/s eta 0:00:00
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 166.1 MB/s eta 0:00:00
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 114.7 MB/s eta 0:00:00
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 332.9 MB/s eta 0:00:00
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 364.4 MB/s eta 0:00:00
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 341.4 MB/s eta 0:00:00
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 374.4 MB/s eta 0:00:00
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 383.1 MB/s eta 0:00:00
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
# - Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 449.8 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 510.3 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 442.7 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.13.1-py3-none-any.whl (6.2 MB)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 470.5 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 509.9 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.48.3-py3-none-any.whl (9.7 MB)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 546.8 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.28.1-py3-none-any.whl (464 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.2.0-py3-none-any.whl (184 kB)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 489.5 MB/s eta 0:00:00
# | Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-24.2-py3-none-any.whl (65 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 520.6 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 568.5 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (461 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 567.4 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.17.0-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.5-py3-none-any.whl (134 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.4.2-py3-none-any.whl (1.7 MB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 292.1 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl (64 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (143 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 917.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.3.0-py3-none-any.whl (128 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# Installing collected packages: triton, nvidia-cusparselt-cu12, mpmath, huggingface, urllib3, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, charset-normalizer, requests, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# \ Creating objects...
# └── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
# ...
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# Image saved, took 85.16s
# / Creating objects...
# ├── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# └── 🔨 Created function Pricer.download_model_to_folder.
# Finished image build for im-4ZCGCDcUFVqQRtI9I2rsxj
# / Creating objects...
# ├── 🔨 Created mount c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\price
# └── 🔨 Created function Pricer.download_model_to_folder.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# └── 🔨 Created function Pricer.download_model_to_folder.
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# ├── 🔨 Created function Pricer.download_model_to_folder.
# └── - Creating function Pricer.*...
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# ├── 🔨 Created function Pricer.download_model_to_folder.
# └── \ Creating function Pricer.*...
# / Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# ├── 🔨 Created function Pricer.download_model_to_folder.
# └── 🔨 Created function Pricer.*.
# \ Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# ├── 🔨 Created function Pricer.download_model_to_folder.
# └── 🔨 Created function Pricer.*.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# ├── 🔨 Created function Pricer.download_model_to_folder.
# └── 🔨 Created function Pricer.*.
#
# ✓ Created objects.
# ├── 🔨 Created mount
# │   c:\Users\e022280\VScode\LLMEng\llm_engineering\week8\pricer_service2.py
# ├── 🔨 Created function Pricer.download_model_to_folder.
# └── 🔨 Created function Pricer.*.
# ✓ App deployed in 1728.513s! 🎉
#
# View Deployment:
# https://modal.com/apps/shekartrash/main/deployed/pricer-service

# %%
Pricer = modal.Cls.lookup("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(reply)
# Out:
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py:84: DeprecationError: 2025-01-27: `modal.Cls.lookup` is deprecated and will be removed in a future release. It can be replaced with `modal.Cls.from_name`.
#
# See https://modal.com/docs/guide/modal-1-0-migration for more information.
#   self._context.run(self._callback, *self._args)
# 133.0

# %% [markdown]
# # Optional: Keeping Modal warm
#
# ## A way to improve the speed of the Modal pricer service
#
# A student mentioned to me that he was concerned by how slow Modal seems to be. The reason is that Modal puts our service to sleep if we don't use it, and then it takes 2.5 minutes to spin back up.
#
# I've added a utility called `keep_warm.py` that will keep our Modal warm by pinging it every 30 seconds.
#
# To use the utliity, bring up a new Terminal (Mac) or Anaconda prompt (Windows), ensure the environment is activated with `conda activate llms`
#
# Then run: `python keep_warm.py` from within the week8 drectory.
#
# Remember to press ctrl+C or exit the window when you no longer need Modal running.

# %% [markdown]
# ## And now introducing our Agent class

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 2nd generation")
# Out:
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py:84: DeprecationError: 2025-01-27: `modal.Cls.lookup` is deprecated and will be removed in a future release. It can be replaced with `modal.Cls.from_name`.
#
# See https://modal.com/docs/guide/modal-1-0-migration for more information.
#   self._context.run(self._callback, *self._args)
# 299.0

# %%
agent = SpecialistAgent()
agent.price("iPhone latest Model ")
# Out:
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py:84: DeprecationError: 2025-01-27: `modal.Cls.lookup` is deprecated and will be removed in a future release. It can be replaced with `modal.Cls.from_name`.
#
# See https://modal.com/docs/guide/modal-1-0-migration for more information.
#   self._context.run(self._callback, *self._args)
# 700.0
